# %% [markdown]
# In \[1\]:
#
#     import pandas as pd
#     import numpy as np
#     import scipy
#     from scipy import stats
#     import seaborn as sns
#
#     Matplotlib is building the font cache; this may take a moment.
#
# In \[2\]:
#
#     data=pd.read_csv("Cutlets.csv") #importing data
#     data
#
# Out\[2\]:
#
# |     | Unit A | Unit B |
# |-----|--------|--------|
# | 0   | 6.8090 | 6.7703 |
# | 1   | 6.4376 | 7.5093 |
# | 2   | 6.9157 | 6.7300 |
# | 3   | 7.3012 | 6.7878 |
# | 4   | 7.4488 | 7.1522 |
# | 5   | 7.3871 | 6.8110 |
# | 6   | 6.8755 | 7.2212 |
# | 7   | 7.0621 | 6.6606 |
# | 8   | 6.6840 | 7.2402 |
# | 9   | 6.8236 | 7.0503 |
# | 10  | 7.3930 | 6.8810 |
# | 11  | 7.5169 | 7.4059 |
# | 12  | 6.9246 | 6.7652 |
# | 13  | 6.9256 | 6.0380 |
# | 14  | 6.5797 | 7.1581 |
# | 15  | 6.8394 | 7.0240 |
# | 16  | 6.5970 | 6.6672 |
# | 17  | 7.2705 | 7.4314 |
# | 18  | 7.2828 | 7.3070 |
# | 19  | 7.3495 | 6.7478 |
# | 20  | 6.9438 | 6.8889 |
# | 21  | 7.1560 | 7.4220 |
# | 22  | 6.5341 | 6.5217 |
# | 23  | 7.2854 | 7.1688 |
# | 24  | 6.9952 | 6.7594 |
# | 25  | 6.8568 | 6.9399 |
# | 26  | 7.2163 | 7.0133 |
# | 27  | 6.6801 | 6.9182 |
# | 28  | 6.9431 | 6.3346 |
# | 29  | 7.0852 | 7.5459 |
# | 30  | 6.7794 | 7.0992 |
# | 31  | 7.2783 | 7.1180 |
# | 32  | 7.1561 | 6.6965 |
# | 33  | 7.3943 | 6.5780 |
# | 34  | 6.9405 | 7.3875 |
#
# In \[3\]:
#
#     data.head()
#
# Out\[3\]:
#
# |     | Unit A | Unit B |
# |-----|--------|--------|
# | 0   | 6.8090 | 6.7703 |
# | 1   | 6.4376 | 7.5093 |
# | 2   | 6.9157 | 6.7300 |
# | 3   | 7.3012 | 6.7878 |
# | 4   | 7.4488 | 7.1522 |
#
# In \[4\]:
#
#     data.info() #checking data type
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 35 entries, 0 to 34
#     Data columns (total 2 columns):
#      #   Column  Non-Null Count  Dtype
#     ---  ------  --------------  -----
#      0   Unit A  35 non-null     float64
#      1   Unit B  35 non-null     float64
#     dtypes: float64(2)
#     memory usage: 688.0 bytes
#
# In \[5\]:
#
#     data.describe()#applying descriptive stat
#
# Out\[5\]:
#
# |       | Unit A    | Unit B    |
# |-------|-----------|-----------|
# | count | 35.000000 | 35.000000 |
# | mean  | 7.019091  | 6.964297  |
# | std   | 0.288408  | 0.343401  |
# | min   | 6.437600  | 6.038000  |
# | 25%   | 6.831500  | 6.753600  |
# | 50%   | 6.943800  | 6.939900  |
# | 75%   | 7.280550  | 7.195000  |
# | max   | 7.516900  | 7.545900  |
#
# In \[6\]:
#
#     data.isnull().sum() #checking null values
#
# Out\[6\]:
#
#     Unit A    0
#     Unit B    0
#     dtype: int64
#
# In \[7\]:
#
#     data[data.duplicated()].shape #checking duplicate values
#
# Out\[7\]:
#
#     (0, 2)
#
# In \[8\]:
#
#     Unit_A=pd.Series(data.iloc[:,0])
#     Unit_A
#
# Out\[8\]:
#
#     0     6.8090
#     1     6.4376
#     2     6.9157
#     3     7.3012
#     4     7.4488
#     5     7.3871
#     6     6.8755
#     7     7.0621
#     8     6.6840
#     9     6.8236
#     10    7.3930
#     11    7.5169
#     12    6.9246
#     13    6.9256
#     14    6.5797
#     15    6.8394
#     16    6.5970
#     17    7.2705
#     18    7.2828
#     19    7.3495
#     20    6.9438
#     21    7.1560
#     22    6.5341
#     23    7.2854
#     24    6.9952
#     25    6.8568
#     26    7.2163
#     27    6.6801
#     28    6.9431
#     29    7.0852
#     30    6.7794
#     31    7.2783
#     32    7.1561
#     33    7.3943
#     34    6.9405
#     Name: Unit A, dtype: float64
#
# In \[9\]:
#
#     Unit_B=pd.Series(data.iloc[:,1])
#     Unit_B
#
# Out\[9\]:
#
#     0     6.7703
#     1     7.5093
#     2     6.7300
#     3     6.7878
#     4     7.1522
#     5     6.8110
#     6     7.2212
#     7     6.6606
#     8     7.2402
#     9     7.0503
#     10    6.8810
#     11    7.4059
#     12    6.7652
#     13    6.0380
#     14    7.1581
#     15    7.0240
#     16    6.6672
#     17    7.4314
#     18    7.3070
#     19    6.7478
#     20    6.8889
#     21    7.4220
#     22    6.5217
#     23    7.1688
#     24    6.7594
#     25    6.9399
#     26    7.0133
#     27    6.9182
#     28    6.3346
#     29    7.5459
#     30    7.0992
#     31    7.1180
#     32    6.6965
#     33    6.5780
#     34    7.3875
#     Name: Unit B, dtype: float64
#
# In \[10\]:
#
#     #above two samples mean are different and they are indipendant sample
#
# ### Ho:There is no significant difference in the diameter of the cutlet between two units.<a href="#Ho:There-is-no-significant-difference-in-the-diameter-of-the-cutlet-between-two-units." class="anchor-link">¶</a>
#
# ### Ha:There is a significant difference in the diameter of the cutlet between two units. 2 sample t test is applicable<a href="#Ha:There-is-a-significant-difference-in-the-diameter-of-the-cutlet-between-two-units.-2-sample-t-test-is-applicable" class="anchor-link">¶</a>
#
# In \[11\]:
#
#     # 2-sample 2-tail t test:
#     t_test = stats.ttest_ind(Unit_A,Unit_B)
#     t_test
#
# Out\[11\]:
#
#     Ttest_indResult(statistic=0.7228688704678063, pvalue=0.4722394724599501)
#
# In \[12\]:
#
#     #comparing p value with alpha i.e 0.5 significant level
#
# ### p_value=0.4722) \> (α = 0.05); Accept Null Hypothesis. i.e. μ1 = μ2 ( Thus, there is no difference in diameters of cutlets between two units<a href="#p_value=0.4722)-%3E-(%CE%B1-=-0.05);-Accept-Null-Hypothesis.-i.e.-%CE%BC1-=-%CE%BC2-(-Thus,-there-is-no-difference-in-diameters-of-cutlets-between-two-units" class="anchor-link">¶</a>
#
# # QUESTION NO 2.<a href="#QUESTION-NO-2." class="anchor-link">¶</a>
#
# In \[13\]:
#
#     data=pd.read_csv("labTAT.csv")
#     data
#
# Out\[13\]:
#
# |     | Laboratory 1 | Laboratory 2 | Laboratory 3 | Laboratory 4 |
# |-----|--------------|--------------|--------------|--------------|
# | 0   | 185.35       | 165.53       | 176.70       | 166.13       |
# | 1   | 170.49       | 185.91       | 198.45       | 160.79       |
# | 2   | 192.77       | 194.92       | 201.23       | 185.18       |
# | 3   | 177.33       | 183.00       | 199.61       | 176.42       |
# | 4   | 193.41       | 169.57       | 204.63       | 152.60       |
# | ... | ...          | ...          | ...          | ...          |
# | 115 | 178.49       | 170.66       | 193.80       | 172.68       |
# | 116 | 176.08       | 183.98       | 215.25       | 177.64       |
# | 117 | 202.48       | 174.54       | 203.99       | 170.27       |
# | 118 | 182.40       | 197.18       | 194.52       | 150.87       |
# | 119 | 182.09       | 215.17       | 221.49       | 162.21       |
#
# 120 rows × 4 columns
#
# In \[14\]:
#
#     data.describe()
#
# Out\[14\]:
#
# |       | Laboratory 1 | Laboratory 2 | Laboratory 3 | Laboratory 4 |
# |-------|--------------|--------------|--------------|--------------|
# | count | 120.000000   | 120.000000   | 120.000000   | 120.00000    |
# | mean  | 178.361583   | 178.902917   | 199.913250   | 163.68275    |
# | std   | 13.173594    | 14.957114    | 16.539033    | 15.08508     |
# | min   | 138.300000   | 140.550000   | 159.690000   | 124.06000    |
# | 25%   | 170.335000   | 168.025000   | 188.232500   | 154.05000    |
# | 50%   | 178.530000   | 178.870000   | 199.805000   | 164.42500    |
# | 75%   | 186.535000   | 189.112500   | 211.332500   | 172.88250    |
# | max   | 216.390000   | 217.860000   | 238.700000   | 205.18000    |
#
# In \[15\]:
#
#     data.mean()
#
# Out\[15\]:
#
#     Laboratory 1    178.361583
#     Laboratory 2    178.902917
#     Laboratory 3    199.913250
#     Laboratory 4    163.682750
#     dtype: float64
#
# ### here there are more than 2 samples then we can go to ANOVA test<a href="#here-there-are-more-than-2-samples-then-we-can-go-to-ANOVA-test" class="anchor-link">¶</a>
#
# In \[16\]:
#
#     stats.f_oneway(data.iloc[:,0],data.iloc[:,1],data.iloc[:,2],data.iloc[:,3])
#
# Out\[16\]:
#
#     F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)
#
# In \[17\]:
#
#     #comparing p value with alpha i.e 0.5
#
# ### Inference: As p-value \< (α = 0.05); Reject Null Hypothesis i.e.<a href="#Inference:-As-p-value-%3C-(%CE%B1-=-0.05);-Reject-Null-Hypothesis-i.e." class="anchor-link">¶</a>
#
# ### Atleast one sample TAT population mean is different Thus there is variance or difference in average Turn Around Time (TAT) of reports of the laboratories on their preferred list.<a href="#Atleast-one-sample-TAT-population-mean-is-different-Thus-there-is-variance-or-difference-in-average-Turn-Around-Time-(TAT)-of-reports-of-the-laboratories-on-their-preferred-list." class="anchor-link">¶</a>
#
# # QUESTION NO 3.<a href="#QUESTION-NO-3." class="anchor-link">¶</a>
#
# In \[18\]:
#
#     data=pd.read_csv("BuyerRatio.csv")
#     data
#
# Out\[18\]:
#
# |     | Observed Values | East | West | North | South |
# |-----|-----------------|------|------|-------|-------|
# | 0   | Males           | 50   | 142  | 131   | 70    |
# | 1   | Females         | 435  | 1523 | 1356  | 750   |
#
# In \[19\]:
#
#     data.describe()
#
# Out\[19\]:
#
# |       | East       | West        | North       | South      |
# |-------|------------|-------------|-------------|------------|
# | count | 2.000000   | 2.000000    | 2.000000    | 2.000000   |
# | mean  | 242.500000 | 832.500000  | 743.500000  | 410.000000 |
# | std   | 272.236111 | 976.514465  | 866.205807  | 480.832611 |
# | min   | 50.000000  | 142.000000  | 131.000000  | 70.000000  |
# | 25%   | 146.250000 | 487.250000  | 437.250000  | 240.000000 |
# | 50%   | 242.500000 | 832.500000  | 743.500000  | 410.000000 |
# | 75%   | 338.750000 | 1177.750000 | 1049.750000 | 580.000000 |
# | max   | 435.000000 | 1523.000000 | 1356.000000 | 750.000000 |
#
# In \[20\]:
#
#     import matplotlib.pyplot as plt
#
# In \[22\]:
#
#     sns.distplot(data['East'],color='b')
#     sns.distplot(data['West'],color='y')
#     sns.distplot(data['North'],color='g')
#     sns.distplot(data['South'],color='r')
#     plt.grid()
#
#     C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#       warnings.warn(msg, FutureWarning)
#     C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#       warnings.warn(msg, FutureWarning)
#     C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#       warnings.warn(msg, FutureWarning)
#     C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#       warnings.warn(msg, FutureWarning)
#
# <img src="attachment:vertopal_51ab36b8cfc6445b95b0ff78b0c3f828/e0b18276f9ef5cb07b97e57e1801b4a538926c87.png" class="jp-needs-light-background" />
#
# ## Ho: Independence of categorical variables (male-female buyer rations are similar across regions (does not vary and are not related)<a href="#Ho:-Independence-of-categorical-variables-(male-female-buyer-rations-are-similar-across-regions-(does-not-vary-and-are-not-related)" class="anchor-link">¶</a>
#
# ## Ha: Dependence of categorical variables (male-female buyer rations are NOT similar across regions (does vary and somewhat/significantly related)<a href="#Ha:-Dependence-of-categorical-variables-(male-female-buyer-rations-are-NOT-similar-across-regions-(does-vary-and-somewhat/significantly-related)" class="anchor-link">¶</a>
#
# In \[23\]:
#
#     # Make a contingency table
#     buyer=np.array([[50,142,131,70],[435,1523,1356,750]])
#     buyer
#
# Out\[23\]:
#
#     array([[  50,  142,  131,   70],
#            [ 435, 1523, 1356,  750]])
#
# In \[24\]:
#
#     # Chi2 contengency independence test
#     from scipy.stats import chi2_contingency
#
# In \[25\]:
#
#     chi_2=chi2_contingency(buyer)
#     print("test t = {}, Pvalue = {}".format(chi_2[0], chi_2[1]))
#
#     test t = 1.595945538661058, Pvalue = 0.6603094907091882
#
# In \[26\]:
#
#     #comparing p value with alpha i.e 0.5
#
# ### Inference: As (p-value = 0.6603) \> (α = 0.05); Accept the Null Hypothesis i.e.<a href="#Inference:-As-(p-value-=-0.6603)-%3E-(%CE%B1-=-0.05);-Accept-the-Null-Hypothesis-i.e." class="anchor-link">¶</a>
#
# ### Independence of categorical variables Thus, male-female buyer rations are similar across regions and are not related<a href="#Independence-of-categorical-variables-Thus,-male-female-buyer-rations-are-similar-across-regions-and-are-not-related" class="anchor-link">¶</a>
#
# # QUESTION NO 4.<a href="#QUESTION-NO-4." class="anchor-link">¶</a>
#
# In \[27\]:
#
#     import pandas as pd
#     import numpy as np
#     from scipy.stats import chi2_contingency
#
# In \[30\]:
#
#     data=pd.read_csv("Costomer+OrderForm.csv")
#     data
#
# Out\[30\]:
#
# |     | Phillippines | Indonesia  | Malta      | India      |
# |-----|--------------|------------|------------|------------|
# | 0   | Error Free   | Error Free | Defective  | Error Free |
# | 1   | Error Free   | Error Free | Error Free | Defective  |
# | 2   | Error Free   | Defective  | Defective  | Error Free |
# | 3   | Error Free   | Error Free | Error Free | Error Free |
# | 4   | Error Free   | Error Free | Defective  | Error Free |
# | ... | ...          | ...        | ...        | ...        |
# | 295 | Error Free   | Error Free | Error Free | Error Free |
# | 296 | Error Free   | Error Free | Error Free | Error Free |
# | 297 | Error Free   | Error Free | Defective  | Error Free |
# | 298 | Error Free   | Error Free | Error Free | Error Free |
# | 299 | Error Free   | Defective  | Defective  | Error Free |
#
# 300 rows × 4 columns
#
# In \[31\]:
#
#     data.info()
#
#     <class 'pandas.core.frame.DataFrame'>
#     RangeIndex: 300 entries, 0 to 299
#     Data columns (total 4 columns):
#      #   Column        Non-Null Count  Dtype
#     ---  ------        --------------  -----
#      0   Phillippines  300 non-null    object
#      1   Indonesia     300 non-null    object
#      2   Malta         300 non-null    object
#      3   India         300 non-null    object
#     dtypes: object(4)
#     memory usage: 9.5+ KB
#
# In \[32\]:
#
#     data.Phillippines.value_counts()
#
# Out\[32\]:
#
#     Error Free    271
#     Defective      29
#     Name: Phillippines, dtype: int64
#
# In \[33\]:
#
#     data.Indonesia.value_counts()
#
# Out\[33\]:
#
#     Error Free    267
#     Defective      33
#     Name: Indonesia, dtype: int64
#
# In \[34\]:
#
#     data.Malta.value_counts()
#
# Out\[34\]:
#
#     Error Free    269
#     Defective      31
#     Name: Malta, dtype: int64
#
# In \[35\]:
#
#     data.India.value_counts()
#
# Out\[35\]:
#
#     Error Free    280
#     Defective      20
#     Name: India, dtype: int64
#
# ### Assume Null Hypothesis as Ho: Independence of categorical variables (customer order forms defective % does not varies by centre) Thus, Alternative hypothesis as Ha Dependence of categorical variables (customer order forms defective % varies by centre)<a href="#Assume-Null-Hypothesis-as-Ho:-Independence-of-categorical-variables-(customer-order-forms-defective-%25-does-not-varies-by-centre)-Thus,-Alternative-hypothesis-as-Ha-Dependence-of-categorical-variables-(customer-order-forms-defective-%25-varies-by-centre)" class="anchor-link">¶</a>
#
# In \[36\]:
#
#     # Make a contingency table
#     cust_o_form=np.array([[271,267,269,280],[29,33,31,20]])
#     cust_o_form
#
# Out\[36\]:
#
#     array([[271, 267, 269, 280],
#            [ 29,  33,  31,  20]])
#
# In \[37\]:
#
#     # Chi2 contengency independence test
#     chi_2=chi2_contingency(cust_o_form)
#     print("test t = {}, Pvalue = {}".format(chi_2[0], chi_2[1]))
#
#     test t = 3.858960685820355, Pvalue = 0.2771020991233135
#
# In \[38\]:
#
#     # Compare p_value with α = 0.05
#
# ### Inference: As (p_value = 0.2771) \> (α = 0.05); Accept Null Hypthesis i.e. Independence of categorical variables Thus, customer order forms defective % does not varies by centre<a href="#Inference:-As-(p_value-=-0.2771)-%3E-(%CE%B1-=-0.05);-Accept-Null-Hypthesis-i.e.-Independence-of-categorical-variables-Thus,-customer-order-forms-defective-%25-does-not-varies-by-centre" class="anchor-link">¶</a>
#
# In \[ \]:
